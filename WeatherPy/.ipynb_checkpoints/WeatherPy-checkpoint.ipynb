# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 613

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = 'https://api.openweathermap.org/data/2.5/weather?'

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = (f'q={city}&appid=c2e33234eb9fc22dc30337f09bebc67a&units=metric')
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(url+city_url).json()
        
#         Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | talnakh
# Processing Record 2 of Set 1 | nasir
# Processing Record 3 of Set 1 | chui
# Processing Record 4 of Set 1 | 'ain benian
# Processing Record 5 of Set 1 | grytviken
# Processing Record 6 of Set 1 | port-aux-francais
# Processing Record 7 of Set 1 | iqaluit
# Processing Record 8 of Set 1 | edinburgh of the seven seas
# Processing Record 9 of Set 1 | adamstown
# Processing Record 10 of Set 1 | ribeira grande
# Processing Record 11 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 12 of Set 1 | san patricio
# Processing Record 13 of Set 1 | yellowknife
# Processing Record 14 of Set 1 | bethel
# Processing Record 15 of Set 1 | waitangi
# Processing Record 16 of Set 1 | longyearbyen
# Processing Record 17 of Set 1 | seosan
# Processing Record 18 of Set 1 | tiksi
# Processing Record 19 of Set 1 | isafjordur
# Processing Record 20 of Set 1 | qaqortoq
# Processing Record 21 of Set 1 | tammela
# Processing Record 22 of Set 1 | ushuaia
# Processing Record 23 of Set 1 | boden
# Processing Record 24 of Set 1 | margaret river
# Processing Record 25 of Set 1 | novska
# Processing Record 26 of Set 1 | bocas del toro
# Processing Record 27 of Set 1 | richfield
# Processing Record 28 of Set 1 | port mathurin
# Processing Record 29 of Set 1 | stanley
# Processing Record 30 of Set 1 | covington
# Processing Record 31 of Set 1 | warrnambool
# Processing Record 32 of Set 1 | college
# Processing Record 33 of Set 1 | oquirrh
# Processing Record 34 of Set 1 | illizi
# Processing Record 35 of Set 1 | west island
# Processing Record 36 of Set 1 | utrik
# Processing Record 37 of Set 1 | anadyr
# Processing Record 38 of Set 1 | sao joao da barra
# Processing Record 39 of Set 1 | hasaki
# Processing Record 40 of Set 1 | anqing
# Processing Record 41 of Set 1 | bengkulu
# Processing Record 42 of Set 1 | blackmans bay
# Processing Record 43 of Set 1 | constantia
# Processing Record 44 of Set 1 | thompson
# Processing Record 45 of Set 1 | isle of lewis
# City not found. Skipping...
# Processing Record 46 of Set 1 | kailua-kona
# Processing Record 47 of Set 1 | shangri-la
# City not found. Skipping...
# Processing Record 48 of Set 1 | badger
# Processing Record 49 of Set 1 | haiku-pauwela
# Processing Record 50 of Set 1 | hamilton
# Processing Record 0 of Set 2 | rikaze
# Processing Record 1 of Set 2 | sao vicente
# Processing Record 2 of Set 2 | puerto natales
# Processing Record 3 of Set 2 | cooper's town
# Processing Record 4 of Set 2 | noyabrsk
# Processing Record 5 of Set 2 | invercargill
# Processing Record 6 of Set 2 | bilibino
# Processing Record 7 of Set 2 | moose jaw
# Processing Record 8 of Set 2 | atafu village
# Processing Record 9 of Set 2 | albany
# Processing Record 10 of Set 2 | enewetak
# Processing Record 11 of Set 2 | axim
# Processing Record 12 of Set 2 | rundu
# Processing Record 13 of Set 2 | el bauga
# Processing Record 14 of Set 2 | juankoski
# Processing Record 15 of Set 2 | mount pearl
# Processing Record 16 of Set 2 | suva
# Processing Record 17 of Set 2 | fort st. john
# Processing Record 18 of Set 2 | hawaiian paradise park
# Processing Record 19 of Set 2 | markovo
# Processing Record 20 of Set 2 | verkhnevilyuysk
# Processing Record 21 of Set 2 | la passe
# Processing Record 22 of Set 2 | arraial do cabo
# Processing Record 23 of Set 2 | porto novo
# Processing Record 24 of Set 2 | olonkinbyen
# Processing Record 25 of Set 2 | papatowai
# Processing Record 26 of Set 2 | bredasdorp
# Processing Record 27 of Set 2 
of Set 4 | 'ohonua
# City not found. Skipping...
# Processing Record 1 of Set 4 | ponta delgada
# Processing Record 2 of Set 4 | welshpool
# Processing Record 3 of Set 4 | hobyo
# Processing Record 4 of Set 4 | san antonio de pale
# Processing Record 5 of Set 4 | mount gambier
# Processing Record 6 of Set 4 | junin de los andes
# Processing Record 7 of Set 4 | cabedelo
# Processing Record 8 of Set 4 | tual
# Processing Record 9 of Set 4 | dhuusamarreeb
# Processing Record 10 of Set 4 | padang
# Processing Record 11 of Set 4 | lebu
# Processing Record 12 of Set 4 | ilulissat
# Processing Record 13 of Set 4 | kristiansund
# Processing Record 14 of Set 4 | flying fish cove
# Processing Record 15 of Set 4 | ayaviri
# Processing Record 16 of Set 4 | nar'yan-mar
# Processing Record 17 of Set 4 | san pedro pochutla
# Processing Record 18 of Set 4 | homer
# Processing Record 19 of Set 4 | cova figueira
# Processing Record 20 of Set 4 | mazamari
# Processing Record 21 of Set 4 | dunedin
# Processing Record 22 of Set 4 | chonchi
# Processing Record 23 of Set 4 | gilgit
# Processing Record 24 of Set 4 | smithers
# Processing Record 25 of Set 4 | jieyang
# Processing Record 26 of Set 4 | cao bang
# Processing Record 27 of Set 4 | zangguy
# City not found. Skipping...
# Processing Record 28 of Set 4 | kayyerkan
# Processing Record 29 of Set 4 | uzgen
# Processing Record 30 of Set 4 | puerto baquerizo moreno
# Processing Record 31 of Set 4 | muzayri'
# City not found. Skipping...
# Processing Record 32 of Set 4 | bairagnia
# Processing Record 33 of Set 4 | nampula
# Processing Record 34 of Set 4 | lycksele
# Processing Record 35 of Set 4 | kone
# Processing Record 36 of Set 4 | pakruojis
# Processing Record 37 of Set 4 | taltal
# Processing Record 38 of Set 4 | loveland
# Processing Record 39 of Set 4 | qingnian
# Processing Record 40 of Set 4 | weno
# Processing Record 41 of Set 4 | laikit, laikit ii (dimembe)
# Processing Record 42 of Set 4 | iskateley
# Processing Record 43 of Set 4 | diyadin
# Processing Record 44 of Set 4 | zhicheng
# Processing Record 45 of Set 4 | takoradi
# Processing Record 46 of Set 4 | yatou
# Processing Record 47 of Set 4 | antofagasta
# Processing Record 48 of Set 4 | revda
# Processing Record 49 of Set 4 | carbonear
# Processing Record 0 of Set 5 | mutsu
# Processing Record 1 of Set 5 | port moresby
# Processing Record 2 of Set 5 | el abiodh sidi cheikh
# Processing Record 3 of Set 5 | yarmouth
# Processing Record 4 of Set 5 | hondo
# Processing Record 5 of Set 5 | uliastay
# Processing Record 6 of Set 5 | sarikamis
# Processing Record 7 of Set 5 | undurkhaan
# Processing Record 8 of Set 5 | jieshi
# Processing Record 9 of Set 5 | berdigestyakh
# Processing Record 10 of Set 5 | namibe
# Processing Record 11 of Set 5 | nova xavantina
# Processing Record 12 of Set 5 | tolanaro
# Processing Record 13 of Set 5 | saint-philippe
# Processing Record 14 of Set 5 | punta arenas
# Processing Record 15 of Set 5 | alofi
# Processing Record 16 of Set 5 | keflavik
# Processing Record 17 of Set 5 | hermanus
# Processing Record 18 of Set 5 | rio grande
# Processing Record 19 of Set 5 | afaahiti
# Processing Record 20 of Set 5 | port elizabeth
# Processing Record 21 of Set 5 | dalaba
# Processing Record 22 of Set 5 | yinchuan
# Processing Record 23 of Set 5 | patrocinio
# Processing Record 24 of Set 5 | khandyga
# Processing Record 25 of Set 5 | el granada
# Processing Record 26 of Set 5 | tukrah
# Processing Record 27 of Set 5 | sur
# Processing Record 28 of Set 5 | las higueras
# Processing Record 29 of Set 5 | lensk
# Processing Record 30 of Set 5 | ocean shores
# Processing Record 31 of Set 5 | floro
# Processing Record 32 of Set 5 | malango
# Processing Record 33 of Set 5 | remire-montjoly
# Processing Record 34 of Set 5 | kavieng
# Processing Record 35 of Set 5 | franceville
# Processing Record 36 of Set 5 | caleta de carquin
# Processing Record 37 of Set 5 | motygino
# Processing Record 38 of Set 5 | portage la prairie
# Processing Record 39 of Set 5 | daoukro
# Processing Record 40 of Set 5 | omdurman
# Processing Record 41 of Set 5 | boyolangu
# Processing Record 42 of Set 5 | selfoss
# Processing Record 43 of Set 5 | cole harbour
# Processing Record 44 of Set 5 | tulun
# Processing Record 45 of Set 5 | mercedes
# Processing Record 46 of Set 5 | ketchikan
# Processing Record 47 of Set 5 | huilong
# Processing Record 48 of Set 5 | james island
# City not found. Skipping...
# Processing Record 49 of Set 5 | tulagi
# Processing Record 0 of Set 6 | ust-nera
# Processing Record 1 of Set 6 | wailua homesteads
# Processing Record 2 of Set 6 | enriquillo
# Processing Record 3 of Set 6 | paragominas
# Processing Record 4 of Set 6 | lamar
# Processing Record 5 of Set 6 | macgregor
# Processing Record 6 of Set 6 | rongelap
# Processing Record 7 of Set 6 | mahibadhoo
# Processing Record 8 of Set 6 | salmon arm
# Processing Record 9 of Set 6 | panaba
# Processing Record 10 of Set 6 | trujillo
# Processing Record 11 of Set 6 | at taj
# Processing Record 12 of Set 6 | ytyk-kyuyel'
# City not found. Skipping...
# Processing Record 13 of Set 6 | sorong
# Processing Record 14 of Set 6 | klaksvik
# Processing Record 15 of Set 6 | kodiak
# Processing Record 16 of Set 6 | campo de criptana
# Processing Record 17 of Set 6 | bandar lampung
# Processing Record 18 of Set 6 | yemva
# Processing Record 19 of Set 6 | buka
# Processing Record 20 of Set 6 | reyes
# Processing Record 21 of Set 6 | mogadishu
# Processing Record 22 of Set 6 | farmville
# Processing Record 23 of Set 6 | hotan
# Processing Record 24 of Set 6 | harda khas
# Processing Record 25 of Set 6 | egilsstadir
# Processing Record 26 of Set 6 | danielskuil
# Processing Record 27 of Set 6 | mendoza
# Processing Record 28 of Set 6 | adoni
# Processing Record 29 of Set 6 | tazacorte
# Processing Record 30 of Set 6 | ryotsu-minato
# Processing Record 31 of Set 6 | katsuren-haebaru
# Processing Record 32 of Set 6 | sao mateus
# Processing Record 33 of Set 6 | danilovka
# Processing Record 34 of Set 6 | nova sintra
# Processing Record 35 of Set 6 | aberdeen
# Processing Record 36 of Set 6 | castillos
# Processing Record 37 of Set 6 | huarmey
# Processing Record 38 of Set 6 | mersing
# Processing Record 39 of Set 6 | hangal
# Processing Record 40 of Set 6 | awjilah
# Processing Record 41 of Set 6 | ouani
# Processing Record 42 of Set 6 | porto torres
# Processing Record 43 of Set 6 | lakhi
# Processing Record 44 of Set 6 | mata-utu
# Processing Record 45 of Set 6 | ta`u
# Processing Record 46 of Set 6 | aasiaat
# Processing Record 47 of Set 6 | isangel
# Processing Record 48 of Set 6 | salekhard
# Processing Record 49 of Set 6 | lazarevskoye
# Processing Record 0 of Set 7 | cardigan
# Processing Record 1 of Set 7 | benguela
# Processing Record 2 of Set 7 | puerto del carmen
# Processing Record 3 of Set 7 | vila franca do campo
# Processing Record 4 of Set 7 | port douglas
# Processing Record 5 of Set 7 | sishilichengzi
# Processing Record 5 of Set 10 | waliso
# Processing Record 6 of Set 10 | kakunodatemachi
# Processing Record 7 of Set 10 | plettenberg bay
# Processing Record 8 of Set 10 | la rioja
# Processing Record 9 of Set 10 | karbala
# Processing Record 10 of Set 10 | mareeba
# Processing Record 11 of Set 10 | san andres
# Processing Record 12 of Set 10 | lautoka
# Processing Record 13 of Set 10 | qashyr
# Processing Record 14 of Set 10 | dubrovnik
# Processing Record 15 of Set 10 | anserma
# Processing Record 16 of Set 10 | ad dawadimi
# Processing Record 17 of Set 10 | kasama
# Processing Record 18 of Set 10 | jamaame
# Processing Record 19 of Set 10 | vilyuysk
# Processing Record 20 of Set 10 | ulanhot
# Processing Record 21 of Set 10 | road town
# Processing Record 22 of Set 10 | uturoa
# Processing Record 23 of Set 10 | southam
# Processing Record 24 of Set 10 | bardai
# Processing Record 25 of Set 10 | ciudad tula
# Processing Record 26 of Set 10 | nuku'alofa
# Processing Record 27 of Set 10 | laminusa
# Processing Record 28 of Set 10 | chuguyevka
# Processing Record 29 of Set 10 | nacozari viejo
# Processing Record 30 of Set 10 | misratah
# Processing Record 31 of Set 10 | huittinen
# Processing Record 32 of Set 10 | masvingo
# Processing Record 33 of Set 10 | ribeira brava
# Processing Record 34 of Set 10 | tianshui
# Processing Record 35 of Set 10 | yoichi
# Processing Record 36 of Set 10 | kayangel
# Processing Record 37 of Set 10 | lashio
# Processing Record 38 of Set 10 | margate
# Processing Record 39 of Set 10 | pangody
# Processing Record 40 of Set 10 | vol'sk
# Processing Record 41 of Set 10 | toga village
# City not found. Skipping...
# Processing Record 42 of Set 10 | sao paulo de olivenca
# Processing Record 43 of Set 10 | itapetinga
# Processing Record 44 of Set 10 | arkhangel'sk
# Processing Record 45 of Set 10 | nadym
# Processing Record 46 of Set 10 | bodo
# Processing Record 47 of Set 10 | fort bragg
# Processing Record 48 of Set 10 | stupava
# Processing Record 49 of Set 10 | conception bay south
# Processing Record 0 of Set 11 | devinuwara
# City not found. Skipping...
# Processing Record 1 of Set 11 | chiroqchi
# Processing Record 2 of Set 11 | gurupi
# Processing Record 3 of Set 11 | fort mcmurray
# Processing Record 4 of Set 11 | fale old settlement
# Processing Record 5 of Set 11 | queenstown
# Processing Record 6 of Set 11 | ust'-ilimsk
# Processing Record 7 of Set 11 | touba
# Processing Record 8 of Set 11 | mafeteng
# Processing Record 9 of Set 11 | petropavlovsk-kamchatsky
# Processing Record 10 of Set 11 | endicott
# Processing Record 11 of Set 11 | ancud
# Processing Record 12 of Set 11 | irece
# Processing Record 13 of Set 11 | chaihe
# Processing Record 14 of Set 11 | petrovsk-zabaykal'skiy
# Processing Record 15 of Set 11 | port macquarie
# Processing Record 16 of Set 11 | omaruru
# Processing Record 17 of Set 11 | bandar seri begawan
# Processing Record 18 of Set 11 | abraham's bay
# City not found. Skipping...
# Processing Record 19 of Set 11 | alamogordo
# Processing Record 20 of Set 11 | fenghua
# Processing Record 21 of Set 11 | guitiriz
# Processing Record 22 of Set 11 | lospalos
# Processing Record 23 of Set 11 | kamogawa
# Processing Record 24 of Set 11 | luganville
# Processing Record 25 of Set 11 | aracruz
# Processing Record 26 of Set 11 | vila velha
# Processing Record 27 of Set 11 | trinidad
# Processing Record 28 of Set 11 | gua musang
# Processing Record 29 of Set 11 | tayu
# Processing Record 30 of Set 11 | vadso
# Processing Record 31 of Set 11 | el calafate
# Processing Record 32 of Set 11 | dashiqiao
# Processing Record 33 of Set 11 | melekeok village
# Processing Record 34 of Set 11 | pokrovsk
# Processing Record 35 of Set 11 | san isidro de curuguaty
# Processing Record 36 of Set 11 | berezovyy
# Processing Record 37 of Set 11 | las palmas de gran canaria
# Processing Record 38 of Set 11 | belo sur tsiribihina
# Processing Record 39 of Set 11 | wesselsbron
# Processing Record 40 of Set 11 | broome
# Processing Record 41 of Set 11 | cidreira
# Processing Record 42 of Set 11 | cumaribo
# City not found. Skipping...
# Processing Record 43 of Set 11 | esqueda
# Processing Record 44 of Set 11 | shenjiamen
# Processing Record 45 of Set 11 | hammerfest
# Processing Record 46 of Set 11 | tranovaho
# City not found. Skipping...
# Processing Record 47 of Set 11 | hirara
# Processing Record 48 of Set 11 | aleksandrov gay
# Processing Record 49 of Set 11 | juegang
# Processing Record 0 of Set 12 | hawera
# Processing Record 1 of Set 12 | jaguaribe
# Processing Record 2 of Set 12 | plastun
# Processing Record 3 of Set 12 | viedma
# Processing Record 4 of Set 12 | happy valley-goose bay
# Processing Record 5 of Set 12 | luwuk
# Processing Record 6 of Set 12 | sambava
# Processing Record 7 of Set 12 | taro
# Processing Record 8 of Set 12 | louiseville
# Processing Record 9 of Set 12 | sakakah
# Processing Record 10 of Set 12 | koszalin
# Processing Record 11 of Set 12 | gotsucho
# Processing Record 12 of Set 12 | luena
# Processing Record 13 of Set 12 | tongchuanshi
# Processing Record 14 of Set 12 | xining
# Processing Record 15 of Set 12 | kanniyakumari
# Processing Record 16 of Set 12 | al ghayzah
# Processing Record 17 of Set 12 | talcahuano
# Processing Record 18 of Set 12 | cholpon-ata
# Processing Record 19 of Set 12 | saddle brooke
# City not found. Skipping...
# Processing Record 20 of Set 12 | nicoya
# Processing Record 21 of Set 12 | kerikeri
# Processing Record 22 of Set 12 | viqueque
# Processing Record 23 of Set 12 | banda aceh
# Processing Record 24 of Set 12 | bilajer
# Processing Record 25 of Set 12 | howrah
# Processing Record 26 of Set 12 | manaure
# Processing Record 27 of Set 12 | ghat
# Processing Record 28 of Set 12 | murzuq
# Processing Record 29 of Set 12 | port blair
# Processing Record 30 of Set 12 | bikenibeu village
# Processing Record 31 of Set 12 | roma
# Processing Record 32 of Set 12 | marudi
# City not found. Skipping...
# Processing Record 33 of Set 12 | gornopravdinsk
# Processing Record 34 of Set 12 | san carlos centro
# Processing Record 35 of Set 12 | prince albert
# Processing Record 36 of Set 12 | puerto leguizamo
# Processing Record 37 of Set 12 | ugoofaaru
# Processing Record 38 of Set 12 | porto recanati
# Processing Record 39 of Set 12 | moab
# Processing Record 40 of Set 12 | juneau
# Processing Record 41 of Set 12 | polyarnyy
# Processing Record 42 of Set 12 | aden
# Processing Record 43 of Set 12 | brookings
# Processing Record 44 of Set 12 | yangor
# City not found. Skipping...
# Processing Record 45 of Set 12 | eyl
# Processing Record 46 of Set 12 | krasnyy chikoy
# Processing Record 47 of Set 12 | port saint john's
# Processing Record 48 of Set 12 | parker
# Processing Record 49 of Set 12 | oualidia
# City not found. Skipping...
# Processing Record 0 of Set 13 | port augusta
# Processing Record 1 of Set 13 | yangiyer
# Processing Record 2 of Set 13 | winejok
# City not found. Skipping...
# Processing Record 3 of Set 13 | laiyang
# Processing Record 4 of Set 13 | piti village
# Processing Record 5 of Set 13 | pont-l'abbe
# City not found. Skipping...
# Processing Record 6 of Set 13 | obock
# Processing Record 7 of Set 13 | nogliki
# Processing Record 8 of Set 13 | banyo
# Processing Record 9 of Set 13 | kyzyl-burun
# City not found. Skipping...
# Processing Record 10 of Set 13 | mafinga
# Processing Record 11 of Set 13 | udangudi
# Processing Record 12 of Set 13 | funadhoo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          582
# Lat           582
# Lng           582
# Max Temp      582
# Humidity      582
# Cloudiness    582
# Wind Speed    582
# Country       582
# Date          582
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0            talnakh  69.4865  88.3972    -17.90        84          94
# 1              nasir  15.5894  32.5634     33.81        10           4
# 2               chui -33.6971 -53.4616     16.30        93         100
# 3        'ain benian  36.8028   2.9219     18.03        88          21
# 4          grytviken -54.2811 -36.5092      1.76        90          89
#
#          Wind Speed Country        Date
# City_ID
# 0              2.05      RU  1683495219
# 1              7.22      SD  1683495597
# 2              2.66      UY  1683495597
# 3              0.89      DZ  1683495597
# 4              9.71      GS  1683495597

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                 City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0            talnakh  69.4865  88.3972    -17.90        84          94
# 1              nasir  15.5894  32.5634     33.81        10           4
# 2               chui -33.6971 -53.4616     16.30        93         100
# 3        'ain benian  36.8028   2.9219     18.03        88          21
# 4          grytviken -54.2811 -36.5092      1.76        90          89
#
#          Wind Speed Country        Date
# City_ID
# 0              2.05      RU  1683495219
# 1              7.22      SD  1683495597
# 2              2.66      UY  1683495597
# 3              0.89      DZ  1683495597
# 4              9.71      GS  1683495597

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
temp_x_axis=city_data_df['Lat']
temp_y_axis=city_data_df['Max Temp']
plt.scatter(temp_x_axis,temp_y_axis)

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Temperature (c)')
plt.title('Latitude vs Temperature')

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
hum_x_axis=city_data_df['Lat']
hum_y_axis=city_data_df['Humidity']
plt.scatter(hum_x_axis,hum_y_axis)

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title('Latitude vs Humidity')

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
cloud_x_axis=city_data_df['Lat']
cloud_y_axis=city_data_df['Cloudiness']
plt.scatter(cloud_x_axis,cloud_y_axis)

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title('Latitude vs Cloudiness')

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
wind_x_axis=city_data_df['Lat']
wind_y_axis=city_data_df['Wind Speed']
plt.scatter(wind_x_axis,wind_y_axis)

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title('Latitude vs Wind Speed')

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
(temp_slope,temp_int,temp_r,temp_p,temp_stderr)=linregress(temp_x_axis,temp_y_axis)

(hum_slope,hum_int,hum_r,hum_p,hum_stderr)=linregress(hum_x_axis,hum_y_axis)

(cloud_slope,cloud_int,cloud_r,cloud_p,cloud_stderr)=linregress(cloud_x_axis,cloud_y_axis)

(wind_slope,wind_int,wind_r,wind_p,wind_stderr)=linregress(wind_x_axis,wind_y_axis)

# %%
city_data_df.head()
# Out:
#                 City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0            talnakh  69.4865  88.3972    -17.90        84          94
# 1              nasir  15.5894  32.5634     33.81        10           4
# 2               chui -33.6971 -53.4616     16.30        93         100
# 3        'ain benian  36.8028   2.9219     18.03        88          21
# 4          grytviken -54.2811 -36.5092      1.76        90          89
#
#          Wind Speed Country        Date
# City_ID
# 0              2.05      RU  1683495219
# 1              7.22      SD  1683495597
# 2              2.66      UY  1683495597
# 3              0.89      DZ  1683495597
# 4              9.71      GS  1683495597

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df=pd.DataFrame(city_data_df[city_data_df['Lat']>=0])

# Display sample data
northern_hemi_df.head()
# Out:
#                    City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0               talnakh  69.4865  88.3972    -17.90        84          94
# 1                 nasir  15.5894  32.5634     33.81        10           4
# 3           'ain benian  36.8028   2.9219     18.03        88          21
# 6               iqaluit  63.7506 -68.5145     -3.15        73          20
# 9        ribeira grande  38.5167 -28.7000     18.21        96         100
#
#          Wind Speed Country        Date
# City_ID
# 0              2.05      RU  1683495219
# 1              7.22      SD  1683495597
# 3              0.89      DZ  1683495597
# 6              8.23      CA  1683495352
# 9              8.49      PT  1683495172

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df=pd.DataFrame(city_data_df[city_data_df['Lat']<=0])

# Display sample data
southern_hemi_df.head()
# Out:
#                                 City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 2                               chui -33.6971  -53.4616     16.30        93
# 4                          grytviken -54.2811  -36.5092      1.76        90
# 5                  port-aux-francais -49.3500   70.2167      4.04        65
# 7        edinburgh of the seven seas -37.0676  -12.3116     14.62        65
# 8                          adamstown -25.0660 -130.1015     21.61        59
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 2               100        2.66      UY  1683495597
# 4                89        9.71      GS  1683495597
# 5                95       12.30      TF  1683495597
# 7                41        2.69      SH  1683495598
# 8               100       10.31      PN  1683495598

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
nh_x_axis = northern_hemi_df['Lat']
nh_y_axis = northern_hemi_df['Max Temp']
plt.scatter(nh_x_axis,nh_y_axis)

plt.xlabel('Latitude')
plt.ylabel('Temperature (c)')
plt.title('Northern Hemisphere: Latitude vs Temperature')

(nh_slope,nh_int,nh_r,nh_p,nh_stderr)=linregress(nh_x_axis,nh_y_axis)
regress_values = nh_x_axis*nh_slope + nh_int
line_eq='y = ' + str(round(nh_slope,2)) + 'x + ' + str(round(nh_int,2))

plt.plot(nh_x_axis,regress_values,color='r')
plt.annotate(line_eq,(0,-10))

print(f'R Vaule: {nh_r}')
      
plt.show()
# Out:
# R Vaule: -0.8176236032273755

# %%
# Linear regression on Southern Hemisphere
sh_x_axis = southern_hemi_df['Lat']
sh_y_axis = southern_hemi_df['Max Temp']
plt.scatter(sh_x_axis,sh_y_axis)

plt.xlabel('Latitude')
plt.ylabel('Temperature (c)')
plt.title('Southern Hemisphere: Latitude vs Temperature')

(sh_slope,sh_int,sh_r,sh_p,sh_stderr)=linregress(sh_x_axis,sh_y_axis)
regress_values = sh_x_axis*sh_slope + nh_int
line_eq='y = ' + str(round(sh_slope,2)) + 'x + ' + str(round(sh_int,2))

plt.plot(sh_x_axis,regress_values,color='r')
plt.annotate(line_eq,(-20,5))

print(f'R Vaule: {sh_r}')
      
plt.show()
# Out:
# R Vaule: 0.782400145241219

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
nh_x_axis = northern_hemi_df['Lat']
nh_y_axis = northern_hemi_df['Humidity']
plt.scatter(nh_x_axis,nh_y_axis)

plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title('Northern Hemisphere: Latitude vs Humidity')

(nh_slope,nh_int,nh_r,nh_p,nh_stderr)=linregress(nh_x_axis,nh_y_axis)
regress_values = nh_x_axis*nh_slope + nh_int
line_eq='y = ' + str(round(nh_slope,2)) + 'x + ' + str(round(nh_int,2))

plt.plot(nh_x_axis,regress_values,color='r')
plt.annotate(line_eq,(50,20))

print(f'R Vaule: {nh_r}')
      
plt.show()
# Out:
# R Vaule: 0.07502762225707528

# %%
# Southern Hemisphere
sh_x_axis = southern_hemi_df['Lat']
sh_y_axis = southern_hemi_df['Humidity']
plt.scatter(sh_x_axis,sh_y_axis)

plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title('Southern Hemisphere: Latitude vs Humidity')

(sh_slope,sh_int,sh_r,sh_p,sh_stderr)=linregress(sh_x_axis,sh_y_axis)
regress_values = sh_x_axis*sh_slope + nh_int
line_eq='y = ' + str(round(sh_slope,2)) + 'x + ' + str(round(sh_int,2))

plt.plot(sh_x_axis,regress_values,color='r')
plt.annotate(line_eq,(-50,50))

print(f'R Vaule: {sh_r}')
      
plt.show()
# Out:
# R Vaule: 0.1504999925399549

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
nh_x_axis = northern_hemi_df['Lat']
nh_y_axis = northern_hemi_df['Cloudiness']
plt.scatter(nh_x_axis,nh_y_axis)

plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title('Northern Hemisphere: Latitude vs Cloudiness')

(nh_slope,nh_int,nh_r,nh_p,nh_stderr)=linregress(nh_x_axis,nh_y_axis)
regress_values = nh_x_axis*nh_slope + nh_int
line_eq='y = ' + str(round(nh_slope,2)) + 'x + ' + str(round(nh_int,2))

plt.plot(nh_x_axis,regress_values,color='r')
plt.annotate(line_eq,(50,20))

print(f'R Vaule: {nh_r}')
      
plt.show()
# Out:
# R Vaule: 0.062057098373020154

# %%
# Southern Hemisphere
sh_x_axis = southern_hemi_df['Lat']
sh_y_axis = southern_hemi_df['Cloudiness']
plt.scatter(sh_x_axis,sh_y_axis)

plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title('Southern Hemisphere: Latitude vs Cloudiness')

(sh_slope,sh_int,sh_r,sh_p,sh_stderr)=linregress(sh_x_axis,sh_y_axis)
regress_values = sh_x_axis*sh_slope + nh_int
line_eq='y = ' + str(round(sh_slope,2)) + 'x + ' + str(round(sh_int,2))

plt.plot(sh_x_axis,regress_values,color='r')
plt.annotate(line_eq,(-50,50))

print(f'R Vaule: {sh_r}')
      
plt.show()
# Out:
# R Vaule: -0.04824367715173854

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
nh_x_axis = northern_hemi_df['Lat']
nh_y_axis = northern_hemi_df['Wind Speed']
plt.scatter(nh_x_axis,nh_y_axis)

plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title('Northern Hemisphere: Latitude vs Wind Speed')

(nh_slope,nh_int,nh_r,nh_p,nh_stderr)=linregress(nh_x_axis,nh_y_axis)
regress_values = nh_x_axis*nh_slope + nh_int
line_eq='y = ' + str(round(nh_slope,2)) + 'x + ' + str(round(nh_int,2))

plt.plot(nh_x_axis,regress_values,color='r')
plt.annotate(line_eq,(0,12))

print(f'R Vaule: {nh_r}')
      
plt.show()
# Out:
# R Vaule: -0.043317592054707754

# %%
# Southern Hemisphere
sh_x_axis = southern_hemi_df['Lat']
sh_y_axis = southern_hemi_df['Wind Speed']
plt.scatter(sh_x_axis,sh_y_axis)

plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title('Southern Hemisphere: Latitude vs Wind Speed')

(sh_slope,sh_int,sh_r,sh_p,sh_stderr)=linregress(sh_x_axis,sh_y_axis)
regress_values = sh_x_axis*sh_slope + nh_int
line_eq='y = ' + str(round(sh_slope,2)) + 'x + ' + str(round(sh_int,2))

plt.plot(sh_x_axis,regress_values,color='r')
plt.annotate(line_eq,(-15,12))

print(f'R Vaule: {sh_r}')
      
plt.show()
# Out:
# R Vaule: -0.12556795691183412

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
